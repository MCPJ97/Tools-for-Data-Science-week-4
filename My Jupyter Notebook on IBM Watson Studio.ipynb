# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Michael Connor Pierce Jones__
#
# My desired occupation is that of a senior data Scientist

# %% [markdown]
# *I would love to work in data science because I enjoy logic and working with information and data to produce valuable and meaningful results, having done so as part of my physics degree. I am excited about the amount of opportunities data science provides to change and improve operations within numerous sectors which are important to our planet and society. I am truly excited about the opportunities present to use mathematics and data science to help the planet, leading to a stable and secure global ecology.*

# %% [markdown]
# ### In the next cell the code provides the value for the area of a circle given it's radius

# %%
import numpy as np
p=(np.pi)
x = int(input("Input radius \n"))
t = p * (x ** 2)
print('The circle has an area of %d' %t)
# Out:
# Input radius
# 28
# The circle has an area of 2463

# %% [markdown]
# I choose Markdown out of
# - Markdown, or
# - HTML
# to write this cell
# ***
# Within it I have included:
# 1. Bullet points
# 2. A horizontal line
# 3. A numbered list
# 4. `A picture of a puppy!`
# ![Cute%20puppy.jpg](attachment:Cute%20puppy.jpg)
